# %%
# %pip install -r ../requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement nltk_tokenize (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for nltk_tokenize

# %%
import sys
import os
import nltk
import networkx as nx
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(os.path.join('..')))
from src.data.attachments import AttachmentTypes, Attachment

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\louis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\louis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\louis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Graph 1

text1 = "Photosynthesis is the process by which plants convert sunlight into chemical energy using chlorophyll. Carbon dioxide and water react to form glucose and oxygen."

graph1, viz_graph1 = Attachment._process_graph(text1)

print(graph1)

# Draw the graph
plt.figure(figsize=(8, 6))
nx.draw(viz_graph1, with_labels=True, node_color="lightblue", edge_color="gray", font_size=10)
plt.show()

# Graph 2

text2 = "RAG knowledge graphs improve information retrieval by linking concepts in a structured way."

graph2, viz_graph2 = Attachment._process_graph(text2)

print(graph2)

# Draw the graph
plt.figure(figsize=(8, 6))
nx.draw(viz_graph2, with_labels=True, node_color="lightblue", edge_color="gray", font_size=10)
plt.show()
# Out:
# Photosynthesis is the process by which plants convert sunlight into chemical energy using chlorophyll. Carbon dioxide and water react to form glucose and oxygen.
# {
#     "nodes": [
#         {
#             "id": "photosynthesis"
#         },
#         {
#             "id": "process"
#         },
#         {
#             "id": "plants"
#         },
#         {
#             "id": "convert"
#         },
#         {
#             "id": "sunlight"
#         },
#         {
#             "id": "chemical"
#         },
#         {
#             "id": "energy"
#         },
#         {
#             "id": "using"
#         },
#         {
#             "id": "chlorophyll"
#         },
#         {
#             "id": "carbon"
#         },
#         {
#             "id": "dioxide"
#         },
#         {
#             "id": "water"
#         },
#         {
#             "id": "react"
#         },
#         {
#             "id": "form"
#         },
#         {
#             "id": "glucose"
# ...
